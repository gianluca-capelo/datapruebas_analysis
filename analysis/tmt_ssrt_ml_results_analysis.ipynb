# %% [markdown]
# # Análisis de Resultados ML - TMT SSRT

# %%
import pandas as pd

df = pd.read_csv("../results/regression/2026-01-26_1901/ssrt/tmt_ssrt/summary.csv")
df
# Out:
#                    model        r2          mse        mae  \
# 0         DummyRegressor -0.011869  2696.308288  40.421441
# 1       LinearRegression -0.207797  3218.393023  45.279223
# 2                  Ridge -0.011669  2695.773690  40.501880
# 3                  Lasso -0.015558  2706.136094  40.511675
# 4           XGBRegressor -0.320542  3518.822682  46.661325
# 5             ElasticNet -0.012988  2699.290450  40.461915
# 6                    SVR -0.012541  2698.097458  40.285499
# 7  RandomForestRegressor -0.104146  2942.194982  42.953788
#
#                                               y_true  \
# 0  [235, 132, 205, 94, 175, 213, 255, 270, 201, 2...
# 1  [235, 132, 205, 94, 175, 213, 255, 270, 201, 2...
# 2  [235, 132, 205, 94, 175, 213, 255, 270, 201, 2...
# 3  [235, 132, 205, 94, 175, 213, 255, 270, 201, 2...
# 4  [235, 132, 205, 94, 175, 213, 255, 270, 201, 2...
# 5  [235, 132, 205, 94, 175, 213, 255, 270, 201, 2...
# 6  [235, 132, 205, 94, 175, 213, 255, 270, 201, 2...
# 7  [235, 132, 205, 94, 175, 213, 255, 270, 201, 2...
#
#                                               y_pred
# 0  [224.5680473372781, 225.17751479289942, 224.74...
# 1  [277.4467398629047, 235.94749978816222, 246.88...
# 2  [227.1066444973185, 225.9692969955806, 226.135...
# 3  [224.5680473372781, 225.29743688324888, 224.74...
# 4  [263.0732727050781, 221.3926239013672, 210.432...
# 5  [224.5680473372781, 225.17751479289942, 224.74...
# 6  [232.01157122586665, 231.2820123542773, 231.64...
# 7  [243.49798161685257, 229.42316859092355, 225.5...

# %%
import sys
sys.path.insert(0, '..')

from src.model.datasetbuilder.dataset_builder import DatasetBuilder

# Cargar el dataset usado para los modelos
builder = DatasetBuilder()
X, y, feature_names, target_name = builder.get_dataset('tmt_ssrt')

# Crear DataFrame con los features para explorar
df_features = pd.DataFrame(X, columns=feature_names)
df_features['target'] = y

print(f"Dataset: tmt_ssrt")
print(f"Samples: {X.shape[0]}, Features: {X.shape[1]}")
print(f"Target: {target_name}")
df_features.head()
# Out:
# WARNING:src.model.datasetbuilder.dataset_builder:Excluding 18 subjects without both PART_A and PART_B trials: ['030720fd-dc61-422b-bdf2-2db9457d2f1c', '13a02b33-8657-43d3-8fc5-c2e3d5efb0e5', '1d0fc2b7-c2a2-43bd-b00c-ab6b0a7ff722', '1e8869b5-564e-4104-b7e7-84cb6a8edf11', '5f6e5399-a575-4a52-91a7-136356728a8a']...
# Dataset: tmt_ssrt
# Samples: 170, Features: 170
# Target: ssrt
#    area_difference_from_ideal_PART_A  area_difference_from_ideal_PART_B  \
# 0                        1248.241760                        1796.087299
# 1                        2413.761789                        1812.318829
# 2                        1912.416306                        2522.437769
# 3                         562.414053                        1019.843303
# 4                        1689.909682                        2211.550752
#
#    average_duration_PART_A  average_duration_PART_B  \
# 0               405.648148               254.833333
# 1               228.515133               243.894136
# 2               250.837654               427.569841
# 3                83.178571               153.171429
# 4               233.660556               220.447619
#
#    correct_targets_touches_PART_A  correct_targets_touches_PART_B  \
# 0                            10.0                            10.0
# 1                            10.0                            10.0
# 2                            10.0                            10.0
# 3                            10.0                            10.0
# 4                            10.0                            10.0
#
#    distance_difference_from_ideal_PART_A  \
# 0                              24.640867
# 1                              30.372466
# 2                              25.773707
# 3                              16.217879
# 4                              26.080216
#
#    distance_difference_from_ideal_PART_B  hesitation_avg_speed_PART_A  \
# 0                              27.778190                     0.104522
# 1                              28.551063                     0.230457
# 2                              37.600730                     0.199273
# 3                              15.335298                     0.216958
# 4                              31.505984                     0.164402
#
#    hesitation_avg_speed_PART_B  ...  travel_avg_speed_PART_B  \
# 0                     0.119332  ...                 0.229479
# 1                     0.215996  ...                 0.427479
# 2                     0.165295  ...                 0.347062
# 3                     0.225781  ...                 0.337168
# 4                     0.166642  ...                 0.337950
#
#    travel_distance_PART_A  travel_distance_PART_B  travel_time_PART_A  \
# 0              646.745078              535.078794         2243.666667
# 1              582.482537              505.496986         1315.100000
# 2              571.831044              441.058361         1491.222222
# 3              632.437384              774.719988         1759.000000
# 4              699.883714              694.794568         2243.400000
#
#    travel_time_PART_B  valid_interval_count_PART_A  \
# 0         2366.500000                   758.000000
# 1         1163.222222                   495.600000
# 2         1237.555556                   397.888889
# 3         2284.000000                   405.000000
# 4         2037.500000                   456.300000
#
#    valid_interval_count_PART_B  wrong_targets_touches_PART_A  \
# 0                   757.000000                           0.0
# 1                   728.555556                           0.0
# 2                   593.111111                           0.0
# 3                   945.500000                           0.0
# 4                   588.000000                           0.0
#
#    wrong_targets_touches_PART_B  target
# 0                           0.0     235
# 1                           0.0     132
# 2                           0.0     205
# 3                           0.0      94
# 4                           0.0     175
#
# [5 rows x 171 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(8, 5))
sns.histplot(y, kde=True, ax=ax)
ax.set_xlabel(f'{target_name} (ms)')
ax.set_ylabel('Frecuencia')
ax.set_title(f'Distribución del Target: {target_name}')
ax.axvline(y.mean(), color='red', linestyle='--', label=f'Media: {y.mean():.1f}')
ax.axvline(y.min(), color='gray', linestyle=':', label=f'Min: {y.min():.1f}')
ax.axvline(y.max(), color='gray', linestyle=':', label=f'Max: {y.max():.1f}')
ax.legend()
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5))
df_sorted = df.sort_values('mae')
sns.barplot(data=df_sorted, x='model', y='mae', ax=ax)
ax.set_xlabel('Modelo')
ax.set_ylabel('MAE (ms)')
ax.set_title('Mean Absolute Error por Modelo')
ax.tick_params(axis='x', rotation=45)
ax.axhline(df['mae'].min(), color='green', linestyle='--', alpha=0.7, label=f'Mejor MAE: {df["mae"].min():.1f}')
ax.legend()
plt.tight_layout()
plt.show()
