# %% [markdown]
# # Análisis de Métricas de Dispersión

# %%
import sys
from pathlib import Path

# Add project root to path
PROJECT_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.config import REGRESSION_ANALYSIS_FOLDER

# %%
TIMESTAMP = "2026-01-26_1901"
csv_path = Path(REGRESSION_ANALYSIS_FOLDER) / "consolidated" / "combined_summary_with_dispersion_2026-02-03_2051_2026-02-03_2053.csv"
df = pd.read_csv(csv_path)
df.head()
# Out:
#                    model        r2          mse        mae  \
# 0  RandomForestRegressor -0.031470     2.481419   1.306021
# 1  RandomForestRegressor  0.043593     0.491841   0.566098
# 2  RandomForestRegressor -0.115545  2952.228661  42.644893
# 3  RandomForestRegressor  0.093048    91.560619   7.389872
# 4  RandomForestRegressor -0.031302     1.070206   0.823345
#
#                                               y_true  \
# 0  [-2.57, -1.35, 1.96, -2.4, 0.89, -1.64, 0.61, ...
# 1  [1.1, 3.135, 3.9000000000000004, 2.5, 3.465, 1...
# 2  [235, 132, 205, 94, 175, 213, 255, 270, 201, 2...
# 3  [56, 24, 26, 26, 30, 50, 24, 24, 28, 30, 38, 3...
# 4  [0.6, 2.8, 4.2, 2.2, 3.6, 0.8, 3.6, 1.53, 2.4,...
#
#                                               y_pred        target  \
# 0  [-0.362733728305731, -0.3213538686715882, 0.54...  sensibilidad
# 1  [2.494386831515488, 2.636100059523809, 2.92082...        K_mean
# 2  [240.1243797445866, 230.65971466919598, 224.62...          ssrt
# ...

# %%
len(df)
# Out:
# 56

# %%
df.drop(columns=["y_true", "y_pred"])
# Out:
#                     model        r2          mse        mae        target  \
# 0   RandomForestRegressor -0.031470     2.481419   1.306021  sensibilidad
# 1   RandomForestRegressor  0.043593     0.491841   0.566098        K_mean
# 2   RandomForestRegressor -0.115545  2952.228661  42.644893          ssrt
# 3   RandomForestRegressor  0.093048    91.560619   7.389872           age
# 4   RandomForestRegressor -0.031302     1.070206   0.823345           K_6
# 5   RandomForestRegressor -0.085420     0.976492   0.805910           K_6
# 6   RandomForestRegressor -0.027288     0.398144   0.499384           K_4
# 7          DummyRegressor -0.009368     2.428246   1.308622  sensibilidad
# 8        LinearRegression -0.137236     2.735861   1.370103  sensibilidad
# 9                   Ridge  0.008136     2.386137   1.285196  sensibilidad
# 10                  Lasso -0.057792     2.544742   1.332462  sensibilidad
# 11           XGBRegressor -0.286130     3.094057   1.428560  sensibilidad
# ...
