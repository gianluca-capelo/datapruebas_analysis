# %% [markdown]
# # Análisis de Métricas de Dispersión

# %%
import sys
from pathlib import Path

# Add project root to path
PROJECT_ROOT = Path().resolve().parents[1]
sys.path.insert(0, str(PROJECT_ROOT))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.config import REGRESSION_ANALYSIS_FOLDER

# %%
TIMESTAMP = "2026-01-26_1901"
csv_path = Path(REGRESSION_ANALYSIS_FOLDER) / TIMESTAMP / "combined_summary_with_dispersion.csv"

df = pd.read_csv(csv_path)
df.head()
# Out:
#               model        r2       mse       mae  \
# 0    DummyRegressor -0.010899  1.154102  0.848730
# 1  LinearRegression -0.116319  1.274456  0.917199
# 2             Ridge  0.027146  1.110667  0.845062
# 3             Lasso -0.044597  1.192574  0.869554
# 4      XGBRegressor -0.019601  1.164037  0.891576
#
#                                               y_true  \
# 0  [0.6, 2.8, 4.2, 2.2, 3.6, 0.8, 3.6, 1.53, 2.4,...
# 1  [0.6, 2.8, 4.2, 2.2, 3.6, 0.8, 3.6, 1.53, 2.4,...
# 2  [0.6, 2.8, 4.2, 2.2, 3.6, 0.8, 3.6, 1.53, 2.4,...
# 3  [0.6, 2.8, 4.2, 2.2, 3.6, 0.8, 3.6, 1.53, 2.4,...
# 4  [0.6, 2.8, 4.2, 2.2, 3.6, 0.8, 3.6, 1.53, 2.4,...
#
#                                               y_pred target dataset  \
# 0  [2.4007608695652176, 2.388804347826087, 2.3811...    K_6   tmt_k
# 1  [1.9545476470260472, 2.314851872336263, 2.5901...    K_6   tmt_k
# 2  [2.1099312703322104, 2.4299778540403247, 2.723...    K_6   tmt_k
# 3  [2.4007608695652176, 2.388804347826087, 2.3811...    K_6   tmt_k
# 4  [1.9128085374832153, 2.0887765884399414, 2.666...    K_6   tmt_k
#
#    sd_y_true  iqr_y_true
# 0   1.071384         1.2
# 1   1.071384         1.2
# 2   1.071384         1.2
# 3   1.071384         1.2
# 4   1.071384         1.2

# %%
len(df)
# Out:
# 24

# %%
df.drop(columns=["y_true", "y_pred"])
# Out:
#                     model        r2          mse        mae        target  \
# 0          DummyRegressor -0.010899     1.154102   0.848730           K_6
# 1        LinearRegression -0.116319     1.274456   0.917199           K_6
# 2                   Ridge  0.027146     1.110667   0.845062           K_6
# 3                   Lasso -0.044597     1.192574   0.869554           K_6
# 4            XGBRegressor -0.019601     1.164037   0.891576           K_6
# 5              ElasticNet -0.056747     1.206445   0.889939           K_6
# 6                     SVR -0.011006     1.154224   0.852428           K_6
# 7   RandomForestRegressor  0.012825     1.127017   0.854177           K_6
# 8          DummyRegressor -0.011869  2696.308288  40.421441          ssrt
# 9        LinearRegression -0.207797  3218.393023  45.279223          ssrt
# 10                  Ridge -0.011669  2695.773690  40.501880          ssrt
# 11                  Lasso -0.015558  2706.136094  40.511675          ssrt
# 12           XGBRegressor -0.320542  3518.822682  46.661325          ssrt
# 13             ElasticNet -0.012988  2699.290450  40.461915          ssrt
# 14                    SVR -0.012541  2698.097458  40.285499          ssrt
# 15  RandomForestRegressor -0.104146  2942.194982  42.953788          ssrt
# 16         DummyRegressor -0.008869     2.753509   1.247817  sensibilidad
# 17       LinearRegression -0.050906     2.868240   1.288025  sensibilidad
# 18                  Ridge  0.023378     2.665497   1.218940  sensibilidad
# 19                  Lasso  0.001427     2.725409   1.235018  sensibilidad
# 20           XGBRegressor -0.201483     3.279211   1.360194  sensibilidad
# 21             ElasticNet  0.017931     2.680365   1.225556  sensibilidad
# 22                    SVR -0.008000     2.751138   1.238495  sensibilidad
# 23  RandomForestRegressor  0.004053     2.718241   1.234420  sensibilidad
#
#        dataset  sd_y_true  iqr_y_true
# 0        tmt_k   1.071384        1.20
# 1        tmt_k   1.071384        1.20
# 2        tmt_k   1.071384        1.20
# 3        tmt_k   1.071384        1.20
# 4        tmt_k   1.071384        1.20
# 5        tmt_k   1.071384        1.20
# 6        tmt_k   1.071384        1.20
# 7        tmt_k   1.071384        1.20
# 8     tmt_ssrt  51.773040       62.25
# 9     tmt_ssrt  51.773040       62.25
# 10    tmt_ssrt  51.773040       62.25
# 11    tmt_ssrt  51.773040       62.25
# 12    tmt_ssrt  51.773040       62.25
# 13    tmt_ssrt  51.773040       62.25
# 14    tmt_ssrt  51.773040       62.25
# 15    tmt_ssrt  51.773040       62.25
# 16  tmt_dprime   1.655711        2.15
# 17  tmt_dprime   1.655711        2.15
# 18  tmt_dprime   1.655711        2.15
# 19  tmt_dprime   1.655711        2.15
# 20  tmt_dprime   1.655711        2.15
# 21  tmt_dprime   1.655711        2.15
# 22  tmt_dprime   1.655711        2.15
# 23  tmt_dprime   1.655711        2.15
