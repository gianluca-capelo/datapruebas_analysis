# %%
import pandas as pd

df = pd.read_csv("/home/gianluca/Research/datapruebas_analysis/data/hand_analysis/2025-11-04_09-43-00/processed/tmt/neuropruebas/metrics.csv")
len(df)
# Out:
# 6648

# %%
df['invalid_cause'].describe()
# Out:
# count                289
# unique                 2
# top       INVALID_LENGTH
# freq                 273
# Name: invalid_cause, dtype: object

# %%
df['invalid_cause'].unique()
# Out:
# array([nan, 'INVALID_LENGTH', 'UNKNOWN_ERROR'], dtype=object)

# %%
#count invalid cause with INVALID_LENGTH
df[df['invalid_cause'] == 'INVALID_LENGTH'].shape[0]
# Out:
# 273

# %%
df[df['invalid_cause'] == 'UNKNOWN_ERROR'].shape[0]
# Out:
# 16

# %%
df[df['invalid_cause'] == 'UNKNOWN_ERROR'][['subject_id', 'invalid_cause', 'error_message']]
# Out:
#                                       subject_id  invalid_cause  \
# 648         aebe388f-ee27-48fe-80c2-0469f07d78ec  UNKNOWN_ERROR
# 2097        f519ef3b-73b9-4009-aef5-fb94de69b966  UNKNOWN_ERROR
# 2361        cf7f1588-a857-4fcf-9469-346110fb7d25  UNKNOWN_ERROR
# 2370        cf7f1588-a857-4fcf-9469-346110fb7d25  UNKNOWN_ERROR
# 2373        cf7f1588-a857-4fcf-9469-346110fb7d25  UNKNOWN_ERROR
# 2374        cf7f1588-a857-4fcf-9469-346110fb7d25  UNKNOWN_ERROR
# 2376        cf7f1588-a857-4fcf-9469-346110fb7d25  UNKNOWN_ERROR
# 2545        41f11ab8-499e-4b69-be1a-ec3d63ce197f  UNKNOWN_ERROR
# 2556        41f11ab8-499e-4b69-be1a-ec3d63ce197f  UNKNOWN_ERROR
# 2957        848afda1-837c-4522-b0d4-fa571133e264  UNKNOWN_ERROR
# 4262        2cf9e9cb-5c0a-48e0-93b0-9c2cb95769be  UNKNOWN_ERROR
# 4351        3aa76e1d-f71e-4b9c-8cbe-503581af9b1f  UNKNOWN_ERROR
# 5319  damianos.care@gmail.com-tmt-plugin_111.csv  UNKNOWN_ERROR
# 5717        deb57c24-6f42-467f-8356-ae4039513131  UNKNOWN_ERROR
# ...
