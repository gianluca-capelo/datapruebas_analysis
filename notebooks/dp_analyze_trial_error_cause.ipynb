# %%
import pandas as pd

df = pd.read_csv("/home/gianluca/Research/datapruebas_analysis/data/hand_analysis/2025-11-04_09-43-00/processed/tmt/datapruebas/metrics.csv")
len(df)
# Out:
# 1100

# %%
df['invalid_cause'].describe()
# Out:
# count                 31
# unique                 2
# top       INVALID_LENGTH
# freq                  22
# Name: invalid_cause, dtype: object

# %%
df['invalid_cause'].unique()
# Out:
# array([nan, 'UNKNOWN_ERROR', 'INVALID_LENGTH'], dtype=object)

# %%
#count invalid cause with INVALID_LENGTH
df[df['invalid_cause'] == 'INVALID_LENGTH'].shape[0]
# Out:
# 22

# %%
df[df['invalid_cause'] == 'UNKNOWN_ERROR'].shape[0]
# Out:
# 9

# %%
df[df['invalid_cause'] == 'UNKNOWN_ERROR'][['subject_id', 'invalid_cause', 'error_message']]
# Out:
#                                subject_id  invalid_cause  \
# 68   5df915f3-cc1a-4469-9a5c-93206bd4954f  UNKNOWN_ERROR
# 215  64bbfefd-5852-4921-8c79-c4f708b9b60a  UNKNOWN_ERROR
# 842  39675e5b-4e50-4bb2-9764-e434c64b3b8a  UNKNOWN_ERROR
# 843  39675e5b-4e50-4bb2-9764-e434c64b3b8a  UNKNOWN_ERROR
# 847  39675e5b-4e50-4bb2-9764-e434c64b3b8a  UNKNOWN_ERROR
# 851  39675e5b-4e50-4bb2-9764-e434c64b3b8a  UNKNOWN_ERROR
# 852  39675e5b-4e50-4bb2-9764-e434c64b3b8a  UNKNOWN_ERROR
# 853  39675e5b-4e50-4bb2-9764-e434c64b3b8a  UNKNOWN_ERROR
# 855  39675e5b-4e50-4bb2-9764-e434c64b3b8a  UNKNOWN_ERROR
#
#                                          error_message
# 68   current_cursor.time must be greater than previ...
# 215  current_cursor.time must be greater than previ...
# 842  current_cursor.time must be greater than previ...
# 843  current_cursor.time must be greater than previ...
# 847  current_cursor.time must be greater than previ...
# 851  current_cursor.time must be greater than previ...
# 852  current_cursor.time must be greater than previ...
# 853  current_cursor.time must be greater than previ...
# 855  current_cursor.time must be greater than previ...
