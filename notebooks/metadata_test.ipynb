# %%
import pandas as pd

from src.config import METADATA_CSV, NEUROPRUEBAS_METADATA_PATH
from src.loader.metadata.datapruebas_metadata import add_datapruebas_metadata

metrics = pd.read_csv('/home/gianluca/Research/datapruebas_analysis/data/hand_analysis/2025-09-28_16-00-13/processed/tmt/neuropruebas/metrics.csv')

# %%
metrics
# Out:
#                                 subject_id         trial_id trial_type  age  \
# 0     df0b8572-3570-4c43-ac9b-017fec2adf22   NEUROPRUEBAS_0     PART_A   30
# 1     df0b8572-3570-4c43-ac9b-017fec2adf22   NEUROPRUEBAS_1     PART_B   30
# 2     df0b8572-3570-4c43-ac9b-017fec2adf22   NEUROPRUEBAS_2     PART_A   30
# 3     df0b8572-3570-4c43-ac9b-017fec2adf22   NEUROPRUEBAS_3     PART_B   30
# 4     df0b8572-3570-4c43-ac9b-017fec2adf22   NEUROPRUEBAS_4     PART_A   30
# ...                                    ...              ...        ...  ...
# 5515  c0a70c2c-6409-4176-9264-781f4dce88db  NEUROPRUEBAS_15     PART_B   30
# 5516  c0a70c2c-6409-4176-9264-781f4dce88db  NEUROPRUEBAS_16     PART_A   30
# 5517  c0a70c2c-6409-4176-9264-781f4dce88db  NEUROPRUEBAS_17     PART_B   30
# 5518  c0a70c2c-6409-4176-9264-781f4dce88db  NEUROPRUEBAS_18     PART_A   30
# 5519  c0a70c2c-6409-4176-9264-781f4dce88db  NEUROPRUEBAS_19     PART_B   30
#
#          gender  is_valid  trial_order_of_appearance  speed_threshold  \
# 0     Masculino      True                          0         0.280745
# 1     Masculino      True                          1         0.280745
# 2     Masculino      True                          2         0.280745
# 3     Masculino      True                          3         0.280745
# 4     Masculino      True                          4         0.280745
# ...         ...       ...                        ...              ...
# 5515  Masculino      True                         15         0.469468
# 5516  Masculino     False                         16         0.469468
# 5517  Masculino      True                         17         0.469468
# 5518  Masculino      True                         18         0.469468
# 5519  Masculino      True                         19         0.469468
#
#       zigzag_amplitude  total_distance  ...  max_duration  \
# 0                  NaN     2961.443571  ...         611.0
# 1         -1683.800000     2004.264113  ...         865.0
# 2                  NaN      602.764093  ...        2181.0
# 3         -2619.666667     2216.741478  ...        6432.0
# 4                  NaN     3082.300046  ...        1813.0
# ...                ...             ...  ...           ...
# 5515       -915.000000     2201.171429  ...        1067.0
# 5516               NaN        0.000000  ...           NaN
# 5517       -808.600000     3892.574991  ...        4766.0
# 5518               NaN     3594.205571  ...        1783.0
# 5519       -375.000000     3176.367260  ...       12616.0
#
#                                      hesitation_periods  \
# 0     [383, 184, 611, 265, 483, 160, 282, 433, 368, ...
# 1     [247, 136, 181, 647, 635, 334, 130, 649, 692, ...
# 2                                      [115, 349, 2181]
# 3                    [1000, 735, 267, 4181, 1205, 6432]
# 4     [572, 502, 832, 832, 261, 183, 598, 1049, 200,...
# ...                                                 ...
# 5515  [1067, 50, 267, 217, 66, 33, 516, 283, 299, 16...
# 5516                                                NaN
# 5517  [350, 50, 134, 67, 166, 84, 233, 233, 531, 283...
# 5518  [49, 134, 83, 276, 141, 750, 33, 300, 100, 299...
# 5519         [149, 17, 633, 866, 649, 12616, 1284, 600]
#
#       correct_targets_touches  wrong_targets_touches  number_of_crosses  \
# 0                        19.0                    0.0                NaN
# 1                        12.0                    0.0                NaN
# 2                         3.0                    1.0                NaN
# 3                         7.0                    0.0                NaN
# 4                        18.0                    0.0                NaN
# ...                       ...                    ...                ...
# 5515                     14.0                    0.0                NaN
# 5516                      NaN                    NaN                NaN
# 5517                     12.0                    8.0                NaN
# 5518                     20.0                    0.0                NaN
# 5519                      6.0                   13.0                NaN
#
#       distance_difference_from_ideal  area_difference_from_ideal  \
# 0                          15.102531                 1138.783474
# 1                          19.965649                 1167.949561
# 2                          66.469884                 1159.167441
# 3                         200.659486                 6170.363070
# 4                          33.621124                 2458.406010
# ...                              ...                         ...
# 5515                       25.387806                 1643.536474
# 5516                             NaN                         NaN
# 5517                      101.606203                 4655.807135
# 5518                       47.783338                 2239.000763
# 5519                       18.148148                 1215.555371
#
#       intra_target_time  inter_target_time  invalid_cause
# 0            897.500000             1040.0            NaN
# 1           1974.181818             1909.0            NaN
# 2            761.000000             3661.0            NaN
# 3           2501.833333             7359.0            NaN
# 4           1261.058824              870.0            NaN
# ...                 ...                ...            ...
# 5515        1477.538462             2006.0            NaN
# 5516                NaN                NaN  UNKNOWN_ERROR
# 5517        1257.545455             8461.0            NaN
# 5518        1059.631579              308.0            NaN
# 5519         886.200000            18055.0            NaN
#
# [5520 rows x 46 columns]

# %%
from src.config import DATAPRUEBAS_METADATA_PATH

metadata = pd.read_csv(NEUROPRUEBAS_METADATA_PATH, sep=';')

# %%
metadata
# Out:
#         username                       last_log                       email  \
# 0        daniela                            NaN      danielamacab@gmail.com
# 1           dani                            NaN         danimacab@gmail.com
# 2       dani1234                            NaN   danielamacab@yahoo.com.ar
# 3         Guanel  2022-05-08 15:37:57.117458+00     caceresnaguel@gmail.com
# 4          Kyrem  2022-03-16 00:00:40.319897+00  ivodiazalejandro@gmail.com
# ..           ...                            ...                         ...
# 740  Mjmorteruiz  2022-11-05 20:06:10.117142+00     mjmorteruiz@hotmail.com
# 741   ccmartincc  2022-11-01 14:53:21.419309+00   correamartin270@gmail.com
# 742   Luciasecin   2022-11-01 16:51:59.12705+00        luciasecin@gmail.com
# 743      lucassg  2022-11-09 15:02:50.016241+00        lucasservi@gmail.com
# 744    Maruycleo  2022-12-02 02:09:19.509206+00       maruycleo@hotmail.com
#
#     is_active                                    id genero nivel_educativo  \
# 0           f  87e81627-5b5e-43e0-af23-61d82151d73d      F               S
# 1           f  fdf5eb50-1131-4488-8dfe-3527a5565854      F               S
# 2           f  b0a8c5b5-fb0e-413c-b4fc-50fe832c4709      F               S
# 3           t  c2030111-c98e-4a81-b7e8-36058ba9dd0f      M               P
# 4           t  48885748-ffa9-49c4-b864-dd6817560b1c      M               S
# ..        ...                                   ...    ...             ...
# 740         t  cd02ab0d-8291-4857-92f8-b3bdf3cbff97      F               U
# 741         t  e900d33a-cdf9-4ba4-9eed-e22cf1ffb44d      M               S
# 742         t  36cd7267-798c-4489-8e63-b4c7bb0df688      F               T
# 743         t  4283b2f7-c357-487e-a484-9a15b8f2300b      M               U
# 744         t  49b5a2f7-0318-4c6b-babc-b0f1fd71eef5      F               U
#
#     nacionalidad pais_de_residencia  año_de_nacimiento  puntos consentimiento
# 0      Argentina          Argentina             1992.0     0.0              t
# 1      Argentina          Argentina             1992.0     0.0              t
# 2      Argentina          Argentina             1992.0     0.0              t
# 3      Argentina          Argentina             1988.0     0.0              t
# 4      Argentino             Italia             2000.0     0.0              t
# ..           ...                ...                ...     ...            ...
# 740     Española             España             1967.0     0.0              t
# 741    Argentina          Argentina             2002.0     0.0              t
# 742    Argentina          Argentina             1999.0     0.0              t
# 743    Argentina          Argentina             1992.0     0.0              t
# 744    Argentina          Argentina             1987.0     0.0              t
#
# [745 rows x 12 columns]

# %%
metadata.columns
# Out:
# Index(['username', 'last_log', 'email', 'is_active', 'id', 'genero',
#        'nivel_educativo', 'nacionalidad', 'pais_de_residencia',
#        'año_de_nacimiento', 'puntos', 'consentimiento'],
#       dtype='object')

# %%
# Convertir a str y minúsculas para evitar problemas de tipos y mayúsculas
subject_vals = metrics['subject_id'].astype(str).str.lower()
mail_vals = metadata['email'].astype(str).str.lower()

# Contar cuántos aparecen en df2.mail
count = subject_vals.isin(mail_vals).sum()
count
# Out:
# 0

# %%
subject_vals
# Out:
# 0       df0b8572-3570-4c43-ac9b-017fec2adf22
# 1       df0b8572-3570-4c43-ac9b-017fec2adf22
# 2       df0b8572-3570-4c43-ac9b-017fec2adf22
# 3       df0b8572-3570-4c43-ac9b-017fec2adf22
# 4       df0b8572-3570-4c43-ac9b-017fec2adf22
#                         ...
# 5515    c0a70c2c-6409-4176-9264-781f4dce88db
# 5516    c0a70c2c-6409-4176-9264-781f4dce88db
# 5517    c0a70c2c-6409-4176-9264-781f4dce88db
# 5518    c0a70c2c-6409-4176-9264-781f4dce88db
# 5519    c0a70c2c-6409-4176-9264-781f4dce88db
# Name: subject_id, Length: 5520, dtype: object

# %%
def retrieve_metadata(metadata_path):
    if metadata_path is None:
        raise ValueError("Metadata path is required for Neuropruebas data")

    tmt_metadata = pd.read_csv(metadata_path, sep=';')

    tmt_metadata = tmt_metadata.drop_duplicates(subset=['id'], keep='first')

    return tmt_metadata



def get_metadata_for_subject(subject_id, metadata_df):
    """
    Busca el subject_id en metadata_df por 'id' o 'mail'.
    Devuelve un diccionario con todas las columnas de la fila encontrada.

    Parámetros:
        subject_id: valor a buscar (puede ser id numérico o email).
        metadata_df (pd.DataFrame): DataFrame con metadata, debe contener 'id' y 'mail'.

    Retorna:
        dict: diccionario con columna:valor de la fila correspondiente.

    Lanza:
        ValueError: si se encuentran múltiples filas coincidentes.
    """

    # Preparar columnas para comparación
    df = metadata_df.copy()
    df["_id_str"] = df["id"].astype(str).str.strip().str.lower()
    df["_mail_str"] = df["email"].astype(str).str.strip().str.lower()

    # Filtrar por id
    matched = df[df["_id_str"] == subject_id]

    # Si no encontró por id, buscar por mail
    if matched.empty:
        matched = df[df["_mail_str"] == subject_id]

    # Si hay más de una fila, lanzar error
    if len(matched) > 1:
        raise ValueError(f"Más de una fila encontrada para subject_id: {subject_id}")
    # Si no hay coincidencias
    if matched.empty:
        raise ValueError(f"Ninguna fila encontrada para subject_id: {subject_id}")

    # Convertir la fila a diccionario y devolver (sin las columnas auxiliares)
    result = matched.iloc[0].drop(labels=["_id_str", "_mail_str"]).to_dict()
    return result


def add_neuropruebas_metadata(metrics_df: pd.DataFrame, subject_col: str = "subject_id", ) -> pd.DataFrame:
    metadata_df = retrieve_metadata(NEUROPRUEBAS_METADATA_PATH)

    # Crear una lista para guardar todos los DataFrames parciales con metadata
    df_list = []

    # Iterar sobre cada subject_id único
    for subject_id in metrics_df[subject_col].unique():
        # Filtrar filas del subject_id actual
        subject_rows = metrics_df[metrics_df[subject_col] == subject_id].copy()

        # Obtener metadata (diccionario)
        metadata = get_metadata_for_subject(subject_id, metadata_df)

        # Agregar metadata como nuevas columnas
        for key, value in metadata.items():
            subject_rows[key] = value

        # Agregar al listado
        df_list.append(subject_rows)

    # Concatenar todos los resultados
    result_df = pd.concat(df_list, ignore_index=True)
    return result_df

# %%
nuevo_df = add_neuropruebas_metadata(metrics, subject_col='subject_id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 nuevo_df = add_neuropruebas_metadata(metrics, subject_col='subject_id')
#
# Cell In[39], line 65, in add_neuropruebas_metadata(metrics_df, subject_col)
#      62 subject_rows = metrics_df[metrics_df[subject_col] == subject_id].copy()
#      64 # Obtener metadata (diccionario)
# ---> 65 metadata = get_metadata_for_subject(subject_id, metadata_df)
#      67 # Agregar metadata como nuevas columnas
#      68 for key, value in metadata.items():
#
# Cell In[39], line 46, in get_metadata_for_subject(subject_id, metadata_df)
#      44 # Si no hay coincidencias
#      45 if matched.empty:
# ---> 46     raise ValueError(f"Ninguna fila encontrada para subject_id: {subject_id}")
#      48 # Convertir la fila a diccionario y devolver (sin las columnas auxiliares)
#      49 result = matched.iloc[0].drop(labels=["_id_str", "_mail_str"]).to_dict()
#
# ValueError: Ninguna fila encontrada para subject_id: facundoruiz2610@gmail.com-tmt-plugin_96.csv

# %%
#chequear si alguno tiene username null
nuevo_df[nuevo_df['age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [subject_id, trial_id, trial_type, age, gender, is_valid, trial_order_of_appearance, speed_threshold, zigzag_amplitude, total_distance, rt, mean_speed, std_speed, peak_speed, mean_acceleration, std_acceleration, peak_acceleration, mean_abs_acceleration, std_abs_acceleration, peak_abs_acceleration, mean_negative_acceleration, std_negative_acceleration, peak_negative_acceleration, hesitation_time, travel_time, search_time, hesitation_distance, travel_distance, search_distance, hesitation_avg_speed, travel_avg_speed, search_avg_speed, state_transitions, hesitation_ratio, total_hesitations, average_duration, max_duration, hesitation_periods, correct_targets_touches, wrong_targets_touches, number_of_crosses, distance_difference_from_ideal, area_difference_from_ideal, intra_target_time, inter_target_time, invalid_cause, username, last_log, email, is_active, id, genero, nivel_educativo, nacionalidad, pais_de_residencia, año_de_nacimiento, puntos, consentimiento]
# Index: []
#
# [0 rows x 58 columns]

# %%
nuevo_df[nuevo_df['subject_id'] == 'facundoruiz2610@gmail.com-tmt-plugin_96.csv']
# Out:
#                                       subject_id         trial_id trial_type  \
# 120  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_0     PART_A
# 121  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_1     PART_B
# 122  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_2     PART_A
# 123  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_3     PART_B
# 124  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_4     PART_A
# 125  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_5     PART_B
# 126  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_6     PART_A
# 127  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_7     PART_B
# 128  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_8     PART_A
# 129  facundoruiz2610@gmail.com-tmt-plugin_96.csv   NEUROPRUEBAS_9     PART_B
# 130  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_10     PART_A
# 131  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_11     PART_B
# 132  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_12     PART_A
# 133  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_13     PART_B
# 134  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_14     PART_A
# 135  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_15     PART_B
# 136  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_16     PART_A
# 137  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_17     PART_B
# 138  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_18     PART_A
# 139  facundoruiz2610@gmail.com-tmt-plugin_96.csv  NEUROPRUEBAS_19     PART_B
#
#      age     gender  is_valid  trial_order_of_appearance  speed_threshold  \
# 120   30  Masculino      True                          0         0.250573
# 121   30  Masculino      True                          1         0.250573
# 122   30  Masculino     False                          2         0.250573
# 123   30  Masculino      True                          3         0.250573
# 124   30  Masculino      True                          4         0.250573
# 125   30  Masculino      True                          5         0.250573
# 126   30  Masculino      True                          6         0.250573
# 127   30  Masculino      True                          7         0.250573
# 128   30  Masculino      True                          8         0.250573
# 129   30  Masculino      True                          9         0.250573
# 130   30  Masculino      True                         10         0.250573
# 131   30  Masculino      True                         11         0.250573
# 132   30  Masculino      True                         12         0.250573
# 133   30  Masculino      True                         13         0.250573
# 134   30  Masculino      True                         14         0.250573
# 135   30  Masculino      True                         15         0.250573
# 136   30  Masculino      True                         16         0.250573
# 137   30  Masculino      True                         17         0.250573
# 138   30  Masculino      True                         18         0.250573
# 139   30  Masculino     False                         19         0.250573
#
#      zigzag_amplitude  total_distance  ...  email  is_active   id  genero  \
# 120               NaN     3128.449763  ...    NaN        NaN  NaN     NaN
# 121      -1571.166667     2213.452520  ...    NaN        NaN  NaN     NaN
# 122               NaN        0.000000  ...    NaN        NaN  NaN     NaN
# 123      -1204.750000     2959.179343  ...    NaN        NaN  NaN     NaN
# 124               NaN     3041.553971  ...    NaN        NaN  NaN     NaN
# 125      -1354.500000     2905.636575  ...    NaN        NaN  NaN     NaN
# 126               NaN     2878.407608  ...    NaN        NaN  NaN     NaN
# 127      -1365.571429     2952.441013  ...    NaN        NaN  NaN     NaN
# 128               NaN     2759.977500  ...    NaN        NaN  NaN     NaN
# 129      -1258.571429     2672.829609  ...    NaN        NaN  NaN     NaN
# 130               NaN     3359.314567  ...    NaN        NaN  NaN     NaN
# 131       -953.888889     3069.997724  ...    NaN        NaN  NaN     NaN
# 132               NaN     3582.422090  ...    NaN        NaN  NaN     NaN
# 133      -1099.555556     3538.534114  ...    NaN        NaN  NaN     NaN
# 134               NaN     3814.291275  ...    NaN        NaN  NaN     NaN
# 135       -863.222222     3317.035060  ...    NaN        NaN  NaN     NaN
# 136               NaN     3136.364718  ...    NaN        NaN  NaN     NaN
# 137      -1026.777778     2950.911133  ...    NaN        NaN  NaN     NaN
# 138               NaN     3019.787917  ...    NaN        NaN  NaN     NaN
# 139               NaN        0.000000  ...    NaN        NaN  NaN     NaN
#
#      nivel_educativo  nacionalidad  pais_de_residencia  año_de_nacimiento  \
# 120              NaN           NaN                 NaN                NaN
# 121              NaN           NaN                 NaN                NaN
# 122              NaN           NaN                 NaN                NaN
# 123              NaN           NaN                 NaN                NaN
# 124              NaN           NaN                 NaN                NaN
# 125              NaN           NaN                 NaN                NaN
# 126              NaN           NaN                 NaN                NaN
# 127              NaN           NaN                 NaN                NaN
# 128              NaN           NaN                 NaN                NaN
# 129              NaN           NaN                 NaN                NaN
# 130              NaN           NaN                 NaN                NaN
# 131              NaN           NaN                 NaN                NaN
# 132              NaN           NaN                 NaN                NaN
# 133              NaN           NaN                 NaN                NaN
# 134              NaN           NaN                 NaN                NaN
# 135              NaN           NaN                 NaN                NaN
# 136              NaN           NaN                 NaN                NaN
# 137              NaN           NaN                 NaN                NaN
# 138              NaN           NaN                 NaN                NaN
# 139              NaN           NaN                 NaN                NaN
#
#      puntos  consentimiento
# 120     NaN             NaN
# 121     NaN             NaN
# 122     NaN             NaN
# 123     NaN             NaN
# 124     NaN             NaN
# 125     NaN             NaN
# 126     NaN             NaN
# 127     NaN             NaN
# 128     NaN             NaN
# 129     NaN             NaN
# 130     NaN             NaN
# 131     NaN             NaN
# 132     NaN             NaN
# 133     NaN             NaN
# 134     NaN             NaN
# 135     NaN             NaN
# 136     NaN             NaN
# 137     NaN             NaN
# 138     NaN             NaN
# 139     NaN             NaN
#
# [20 rows x 58 columns]
