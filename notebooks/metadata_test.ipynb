# %%
import pandas as pd

from src.config import METADATA_CSV
from src.loader.metadata.datapruebas_metadata import add_datapruebas_metadata

metrics = pd.read_csv('/home/gianluca/Research/datapruebas_analysis/data/hand_analysis/2025-09-28_16-00-13/processed/tmt/datapruebas/metrics.csv')

# %%
metrics
# Out:
#                                 subject_id        trial_id trial_type  age  \
# 0     7b1760b5-1341-4b27-bd4c-432e231c5fad   DATAPRUEBAS_0     PART_A   30
# 1     7b1760b5-1341-4b27-bd4c-432e231c5fad   DATAPRUEBAS_1     PART_B   30
# 2     7b1760b5-1341-4b27-bd4c-432e231c5fad   DATAPRUEBAS_2     PART_A   30
# 3     7b1760b5-1341-4b27-bd4c-432e231c5fad   DATAPRUEBAS_3     PART_B   30
# 4     7b1760b5-1341-4b27-bd4c-432e231c5fad   DATAPRUEBAS_4     PART_A   30
# ...                                    ...             ...        ...  ...
# 1095  aba4756b-4bb0-41a5-b76b-2e8d6d406491  DATAPRUEBAS_15     PART_B   30
# 1096  aba4756b-4bb0-41a5-b76b-2e8d6d406491  DATAPRUEBAS_16     PART_A   30
# 1097  aba4756b-4bb0-41a5-b76b-2e8d6d406491  DATAPRUEBAS_17     PART_B   30
# 1098  aba4756b-4bb0-41a5-b76b-2e8d6d406491  DATAPRUEBAS_18     PART_A   30
# 1099  aba4756b-4bb0-41a5-b76b-2e8d6d406491  DATAPRUEBAS_19     PART_B   30
#
#      gender  is_valid  trial_order_of_appearance  speed_threshold  \
# ...

# %%
from src.loader.metadata.datapruebas_metadata import add_datapruebas_metadata
df2 = add_datapruebas_metadata(metrics)
df2.head()
# Out:
#                              subject_id       trial_id trial_type  age  \
# 0  5df915f3-cc1a-4469-9a5c-93206bd4954f  DATAPRUEBAS_0     PART_A   30
# 1  5df915f3-cc1a-4469-9a5c-93206bd4954f  DATAPRUEBAS_1     PART_B   30
# 2  5df915f3-cc1a-4469-9a5c-93206bd4954f  DATAPRUEBAS_2     PART_A   30
# 3  5df915f3-cc1a-4469-9a5c-93206bd4954f  DATAPRUEBAS_3     PART_B   30
# 4  5df915f3-cc1a-4469-9a5c-93206bd4954f  DATAPRUEBAS_4     PART_A   30
#
#    gender  is_valid  trial_order_of_appearance  speed_threshold  \
# 0       M      True                          0         0.279711
# 1       M      True                          1         0.279711
# 2       M      True                          2         0.279711
# 3       M      True                          3         0.279711
# 4       M      True                          4         0.279711
#
#    zigzag_amplitude  total_distance  ...  area_difference_from_ideal  \
# 0               NaN      147.264952  ...                  592.366441
# ...

# %%
from src.config import DATAPRUEBAS_METADATA_PATH

metadata = pd.read_csv(DATAPRUEBAS_METADATA_PATH)

# %%
metadata.columns
# Out:
# Index(['Id sujeto', 'Id ejecucion', 'Estado', 'Fecha de nacimiento', 'Género',
#        'Nivel educativo', 'Nacionalidad', 'Pais de residencia',
#        'Región de residencia'],
#       dtype='object')
