# %%
import pandas as pd

df = pd.read_csv('/home/gianluca/Research/datapruebas_analysis/data/raw/tmt/neuropruebas/subjects/facundoruiz2610@gmail.com-tmt-plugin_96.csv')
df.head(100)
# Out:
#     run_id  condition success timeout failed_images failed_audio failed_video  \
# 0       96          1    true   false            []           []           []
# 1       96          1    true       "             "            "            "
# 2       96          1       "       "             "            "            "
# 3       96          1       "       "             "            "            "
# 4       96          1       "       "             "            "            "
# 5       96          1       "       "             "            "            "
# 6       96          1       "       "             "            "            "
# 7       96          1       "       "             "            "            "
# 8       96          1       "       "             "            "            "
# 9       96          1       "       "             "            "            "
# 10      96          1       "       "             "            "            "
# ...

# %%
df[['position', 'cursor_time', 'x_y_clicked_position', 'trial_type']]
# Out:
#                                              position  \
# 0                                                   "
# 1                                                   "
# 2                                                   "
# 3                                                   "
# 4                                                   "
# 5                                                   "
# 6   ["(477.9541218020757,552.7114763174109)","(474...
# 7                                                   "
# 8   ["(316.395383977137,508.3620160169734)","(316....
# 9                                                   "
# 10                                                  "
# 11  ["(363.9126598080013,582.8057529498507)","(378...
# 12                                                  "
# 13  ["(406.6782080557792,565.3827506889645)","(406...
# 14                                                  "
# 15  ["(379.75175175162275,585.973571542739)","(381...
# ...

# %%
columns_of_interest = [str(i) for i in range(20)]
df[df['trial_type'] == 'trail-making-test'][['trial_type','position', 'cursor_time', 'x_y_clicked_position'] + columns_of_interest]
# Out:
#            trial_type                                           position  \
# 6   trail-making-test  ["(477.9541218020757,552.7114763174109)","(474...
# 8   trail-making-test  ["(316.395383977137,508.3620160169734)","(316....
# 11  trail-making-test  ["(363.9126598080013,582.8057529498507)","(378...
# 13  trail-making-test  ["(406.6782080557792,565.3827506889645)","(406...
# 15  trail-making-test  ["(379.75175175162275,585.973571542739)","(381...
# 17  trail-making-test  ["(542.8943987709237,397.48836526587974)","(54...
# 19  trail-making-test  ["(348.07356786437987,549.5436577245225)","(34...
# 21  trail-making-test  ["(386.08738852907135,351.554995668998)","(384...
# 23  trail-making-test  ["(474.7863034133514,248.6008914001253)","(474...
# 25  trail-making-test  ["(395.5908436952442,213.75488687835298)","(40...
# 27  trail-making-test  ["(571.4047642694422,254.9365285859021)","(569...
# 29  trail-making-test  ["(344.90574947565557,438.6700069734288)","(34...
# ...

# %%
content1 = [{"content":"4","x":192,"y":484},{"content":"D","x":332,"y":364},{"content":"5","x":252,"y":444},{"content":"E","x":192,"y":529},{"content":"6","x":332,"y":404},{"content":"F","x":512,"y":504},{"content":"7","x":652,"y":344},{"content":"G","x":532,"y":204},{"content":"8","x":472,"y":124},{"content":"H","x":592,"y":284},{"content":"9","x":492,"y":204},{"content":"I","x":432,"y":104},{"content":"10","x":332,"y":264},{"content":"J","x":232,"y":284}]

# %%
content1
# Out:
# [{'content': '4', 'x': 192, 'y': 484},
#  {'content': 'D', 'x': 332, 'y': 364},
#  {'content': '5', 'x': 252, 'y': 444},
#  {'content': 'E', 'x': 192, 'y': 529},
#  {'content': '6', 'x': 332, 'y': 404},
#  {'content': 'F', 'x': 512, 'y': 504},
#  {'content': '7', 'x': 652, 'y': 344},
#  {'content': 'G', 'x': 532, 'y': 204},
#  {'content': '8', 'x': 472, 'y': 124},
#  {'content': 'H', 'x': 592, 'y': 284},
#  {'content': '9', 'x': 492, 'y': 204},
#  {'content': 'I', 'x': 432, 'y': 104},
#  {'content': '10', 'x': 332, 'y': 264},
#  {'content': 'J', 'x': 232, 'y': 284}]
