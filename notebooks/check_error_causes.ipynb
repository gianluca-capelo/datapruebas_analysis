# %%
import pandas as pd

df = pd.read_csv("/home/gianluca/Research/datapruebas_analysis/data/hand_analysis/2025-11-11_10-59-18/analysis.csv")
len(df)
# Out:
# 7508

# %%
df['invalid_cause'].describe()
# Out:
# count                   1529
# unique                     3
# top       CUT_CRITERIA_ERROR
# freq                    1215
# Name: invalid_cause, dtype: object

# %%
df['invalid_cause'].unique()
# Out:
# array([nan, 'CUT_CRITERIA_ERROR', 'INVALID_LENGTH', 'UNKNOWN_ERROR'],
#       dtype=object)

# %%
#count invalid cause with INVALID_LENGTH
df[df['invalid_cause'] == 'INVALID_LENGTH'].shape[0]
# Out:
# 293

# %%
df[df['invalid_cause'] == 'UNKNOWN_ERROR'].shape[0]
# Out:
# 21

# %%
df[df['invalid_cause'] == 'CUT_CRITERIA_ERROR'].shape[0]
# Out:
# 1215

# %%
df[df['invalid_cause'] == 'CUT_CRITERIA_ERROR'][['subject_id', 'invalid_cause', 'error_message']]
# Out:
#                                 subject_id       invalid_cause  \
# 2     df0b8572-3570-4c43-ac9b-017fec2adf22  CUT_CRITERIA_ERROR
# 3     df0b8572-3570-4c43-ac9b-017fec2adf22  CUT_CRITERIA_ERROR
# 5     df0b8572-3570-4c43-ac9b-017fec2adf22  CUT_CRITERIA_ERROR
# 7     df0b8572-3570-4c43-ac9b-017fec2adf22  CUT_CRITERIA_ERROR
# 11    df0b8572-3570-4c43-ac9b-017fec2adf22  CUT_CRITERIA_ERROR
# ...                                    ...                 ...
# 7501  aba4756b-4bb0-41a5-b76b-2e8d6d406491  CUT_CRITERIA_ERROR
# 7503  aba4756b-4bb0-41a5-b76b-2e8d6d406491  CUT_CRITERIA_ERROR
# 7505  aba4756b-4bb0-41a5-b76b-2e8d6d406491  CUT_CRITERIA_ERROR
# 7506  aba4756b-4bb0-41a5-b76b-2e8d6d406491  CUT_CRITERIA_ERROR
# 7507  aba4756b-4bb0-41a5-b76b-2e8d6d406491  CUT_CRITERIA_ERROR
#
#                                           error_message
# 2     Trial NEUROPRUEBAS_4 of subject df0b8572-3570-...
# 3     Trial NEUROPRUEBAS_5 of subject df0b8572-3570-...
# ...
